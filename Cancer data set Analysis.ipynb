# %% [markdown]
# PROBLEM SOLVING
#
# The problem I am trying to solve is to identify the most cancer cases recorded in both male and female gender nd how cancer ranks in causing death in countries

# %%
import pandas as pd
fp=pd.read_excel("/content/Cancer (1) (1).xlsx")
fp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %% [markdown]
# We have loaded the data set then defined the file path of the data set. Then we we imported the library for the data set then we read the data.

# %%
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                     --------------  -----
#  0   Country or Territory                                                                                                                                       207 non-null    object
#  1   Cancer deaths attributable to alcohol
# Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016                       207 non-null    object
#  2   Smoking prevalence male
# ...

# %% [markdown]
# The data type present in the data is object. The data shape of the data frame has 207 rows and 27 columns The data size of the data frame is 43.8+KB

# %%
from tabulate import tabulate

# Get all column names
column_names = fp.columns.tolist()

# Convert column names to a list of lists for tabulate
column_names_table = [[i+1, name] for i, name in enumerate(column_names)]

# Print column names as a table
print(tabulate(column_names_table, headers=["Index", "Column Name"]))
# Out:
#   Index  Column Name
# -------  -----------------------------------------------------------------------------------------------------------------------------------
#       1  Country or Territory
#       2  Cancer deaths attributable to alcohol
#          Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016
#       3  Smoking prevalence male
#          Prevalence (%) of daily smoking for men
#       4  Smoking prevalence female
#          Prevalence (%) of daily smoking for women
#       5  Cancers attributable to infections
#          Proportion of cancers attributable to infections (%), by country
#       6  Obesity prevalence male
#          International variation in the prevalence of obesity, 2016
#       7  Obesity prevalence female
#          International variation in the prevalence of obesity, 2016
#       8  Melanoma skin cancer incidence
#          Age-standardized rate (world) per 100,000, both sexes, 2018
# ...

# %% [markdown]
# I have listed the columns into list

# %%
# Select Column names that will help anaswer your problem
selected_columns = [
     'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
     'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
     'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
     'Most common cancer cases worldwide, females\n2018',
     'Average births per woman\n2010-2015',
     'Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age',
     'Most common cancer cases worldwide, males\n2018',
     'Most common cancer deaths worldwide, females\n2018',
     'Cancer rank as leading cause of death among 30-69\n2016',
     'Most common cancer deaths worldwide, males\n2018',
     'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
     'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018'
]

# Select the relevant columns from the DataFrame
selected_fp = fp[selected_columns]
selected_fp
# Out:
#     Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country  \
# 0                                                   16
# 1                                                 12.9
# 2                                                 15.4
# 3                                                 13.4
# 4                                                 12.2
# ..                                                 ...
# 202                                               12.4
# 203                                                6.6
# 204                                               10.2
# 205                                                8.5
# 206                                                6.6
#
#     Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016  \
# 0                                                  3.2
# 1                                                 19.9
# ...

# %% [markdown]
# This are the selected columns that I will use to solve the problem.

# %%
#Display the first few rows of the DataFrame
selected_fp.head()
# Out:
#   Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country  \
# 0                                                 16
# 1                                               12.9
# 2                                               15.4
# 3                                               13.4
# 4                                               12.2
#
#   Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016  \
# 0                                                3.2
# 1                                               19.9
# 2                                               15.8
# 3                                               21.6
# 4                                               17.1
#
#   Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016  \
# 0                                                7.6
# 1                                               34.9
# ...

# %% [markdown]
#   This are the first few rows of the selected data frame

# %%
#check for missing values
print(selected_fp.isnull().sum())
# Out:
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country    0
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                     0
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                   0
# Most common cancer cases worldwide, females\n2018                                                       0
# Average births per woman\n2010-2015                                                                     0
# Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age     0
# Most common cancer cases worldwide, males\n2018                                                         0
# Most common cancer deaths worldwide, females\n2018                                                      0
# Cancer rank as leading cause of death among 30-69\n2016                                                 0
# ...

# %% [markdown]
# There are no missing values in the selected data frame

# %%
#data types
selected_fp.dtypes
# Out:
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country    object
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                     object
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                   object
# Most common cancer cases worldwide, females\n2018                                                       object
# Average births per woman\n2010-2015                                                                     object
# Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age     object
# Most common cancer cases worldwide, males\n2018                                                         object
# Most common cancer deaths worldwide, females\n2018                                                      object
# ...

# %% [markdown]
# The data type in the columns is obejct thus the selected columns may contain both textual and numeric data. There is need to convert the data into numeric inorder to make a numeric analysis

# %%
# Convert selected numeric columns to numeric data type
numeric_columns = [
     'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
     'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
     'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
     'Most common cancer cases worldwide, females\n2018',
     'Average births per woman\n2010-2015',
     'Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age',
     'Most common cancer cases worldwide, males\n2018',
     'Most common cancer deaths worldwide, females\n2018',
     'Most common cancer deaths worldwide, males\n2018',
     'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
     'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018'
]
selected_fp = selected_fp.copy()
selected_fp[numeric_columns] = selected_fp[numeric_columns].apply(pd.to_numeric, errors='coerce')
selected_fp[numeric_columns]
# Out:
#      Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country  \
# 0                                                 16.0
# 1                                                 12.9
# 2                                                 15.4
# 3                                                 13.4
# 4                                                 12.2
# ..                                                 ...
# 202                                               12.4
# 203                                                6.6
# 204                                               10.2
# 205                                                8.5
# 206                                                6.6
#
#      Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016  \
# 0                                                  3.2
# 1                                                 19.9
# ...

# %% [markdown]
# It represents the percentage represented by the column in each country. For example for column 2 row 0, it represents that 16% of cancer in that country is caused by infections.

# %%
# 1.Check for any missing values
missing_values = selected_fp.isnull().sum()
missing_values
# Out:
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country     23
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                      16
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                    16
# Most common cancer cases worldwide, females\n2018                                                       207
# Average births per woman\n2010-2015                                                                      15
# Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age      50
# Most common cancer cases worldwide, males\n2018                                                         207
# Most common cancer deaths worldwide, females\n2018                                                      207
# Cancer rank as leading cause of death among 30-69\n2016                                                   0
# ...

# %% [markdown]
# All the selected columns have missing values, which ought to be removed in order to make analysis

# %%
# 2.Confirm for any duplicates
duplicates = selected_fp.duplicated().sum()
duplicates
# Out:
# 7

# %%
# 3.Remove missing values
cleaned_fp = selected_fp.dropna()
cleaned_fp
# Out:
# Empty DataFrame
# Columns: [Cancers attributable to infections
# Proportion of cancers attributable to infections (%), by country, Obesity prevalence male
# International variation in the prevalence of obesity, 2016, Obesity prevalence female
# International variation in the prevalence of obesity, 2016, Most common cancer cases worldwide, females
# 2018, Average births per woman
# 2010-2015, Breastfeeding at 12 months
# Percent (%) of children who receive any breast milk at 12 months of age, Most common cancer cases worldwide, males
# 2018, Most common cancer deaths worldwide, females
# 2018, Cancer rank as leading cause of death among 30-69
# 2016, Most common cancer deaths worldwide, males
# 2018, Lung cancer incidence rates, male
# Age-standardized rate (world) per 100,000, all ages, 2018, Lung cancer incidence rates, female
# Age-standardized rate (world) per 100,000, all ages, 2018]
# Index: []

# %%
# Check for any remaining missing values
missing_values = cleaned_fp.isnull().sum()
missing_values
# Out:
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country    0.0
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                     0.0
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                   0.0
# Most common cancer cases worldwide, females\n2018                                                       0.0
# Average births per woman\n2010-2015                                                                     0.0
# Breastfeeding at 12 months\nPercent (%) of children who receive any breast milk at 12 months of age     0.0
# Most common cancer cases worldwide, males\n2018                                                         0.0
# Most common cancer deaths worldwide, females\n2018                                                      0.0
# Cancer rank as leading cause of death among 30-69\n2016                                                 0.0
# ...

# %% [markdown]
#   Confirmed there are no missing values

# %%
#summary statistics
print("\nDescriptive statistics for the numeric columns:")
print(selected_fp.describe())
# Out:
# Descriptive statistics for the numeric columns:
#        Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country  \
# count                                         184.000000
# mean                                           19.080978
# std                                            12.113494
# min                                             3.600000
# 25%                                             9.600000
# 50%                                            16.900000
# 75%                                            25.575000
# max                                            54.800000
#
#        Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016  \
# count                                          191.00000
# mean                                            16.34555
# std                                             11.45113
# min                                              1.60000
# ...

# %% [markdown]
# These are the Summary Statistics for The Numeric data

# %%
# Correlation analysis
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = selected_fp.corr()
correlation_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-ea893e7cbed3> in <cell line: 6>()
#       4
#       5 # Calculate the correlation matrix
# ----> 6 correlation_matrix = selected_fp.corr()
#       7 correlation_matrix
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %%
#correlation matrix
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
selected_fp.groupby('Cancer rank as leading cause of death among 30-69\n2016').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# It shows the rank of cancer in causing death in countries.

# %% [markdown]
# FINDIGS
# 1.In most countries, Cancer ranks the 2nd cause of death in those countries
# 2.Obesity in males correlate to cancer cases by 69%. This suggests that being obe has a chance of leading to cancer.

# %% [markdown]
# CONCLUSIONS
# Cancer is a major cause of death in  most countries and measures againstg cancer should be taken.
# 2. People should endeavour to remain fit so as to minimise chances of getting cancer
# 3.People should minimise smoking as it results to cancer such as lung cancer
